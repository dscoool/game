# %% [markdown]
# # 비디오게임 판매량 및 등급

# %% [markdown]
# 안녕하세요? 데이터사이언스 강사 이천입니다.
#
# 오늘 강의에서는, 비디오게임의 판매량 및 등급 데이터를 가지고
# 데이터 분석 수업을 해 보도록 하겠습니다!!
#
# Part I.
# 1. 데이터 불러오기 (엑셀 파일을 파이썬 콘솔로 불러옵니다!!)
# 2. 불러온 데이터 화면에 출력해보기!!
# 3. 데이터프레임을 가지고 엑셀 데이터 분석해보기!!
#
# 데이터셋: video_games_sale.csv -- 비디오 게임의 판매량 및 등급 데이터셋
#
# Name | Platform | Year_of_Release | Genre | Publisher | NA_Sales |
# 게임명   출시 플랫폼        출시년도        장르    게임출시업체    북미판매량
#
# EU_Sales | JP_Sales | Other_Sales | Global_Sales | Critic_Score
# 유럽 판매량   일본 판매량   기타지역 판매량     세계 판매량       전문가 평점
#
# Critic_Count | User_Score | User_Count | Developer | Rating
# 평가 전문가 수     사용자 평점    사용자평가단 수  게임제작회사     평점
#
# 데이터셋 url :
# https://raw.githubusercontent.com/Datamanim/video/master/video_games_sale.csv

# %% [markdown]
# 한 줄 한 줄씩 따라 쳐 볼까요??
#
# ** 코딩을 배울 동안에는 절대로 CTRL+C V를 사용하지 마세요!! 실력이 늘지 않는답니다!!
#
# 아래 내용을 따라 치면서 실습해 볼게요~!!
#
# [에러가 나면 강사에게 문의해 주세요]
#
# 실행: 위의 'Run'버튼 클릭 / CTRL + ENTER (Mac: Command + Enter)

# %%
#데이터 분석을 하는 모듈(라이브러리)를 판다스(pandas)라고 합니다. 
#해당 모듈을 로드합니다.^^

import pandas as pd

# df라는 변수에 video_games_sale.csv를 불러와보도록 할게요!!
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/video/master/video_games_sale.csv',index_col=0)

# %%
#불러온 df (데이터프레임 - DataFrame)을 출력해 봅시다!!

df
# Out:
#                                    Name Platform  Year_of_Release     Genre  \
# 0                            Wii Sports      Wii           2006.0    Sports
# 1                        Mario Kart Wii      Wii           2008.0    Racing
# 2                     Wii Sports Resort      Wii           2009.0    Sports
# 3                 New Super Mario Bros.       DS           2006.0  Platform
# 4                              Wii Play      Wii           2006.0      Misc
# ...                                 ...      ...              ...       ...
# 6820         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 6821     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 6822  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 6823                             Breach       PC           2011.0   Shooter
# 6824            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
#불러온 데이터프레임의 앞 5행을 불러옵니다!! 
# df.head(20) - 을 타이핑해주세요!!
df.head(5)
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 1         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 2      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 3  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 4               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     15.68     12.76      3.79         3.29         35.52          82.0
# 2     15.61     10.93      3.28         2.95         32.77          80.0
# 3     11.28      9.14      6.50         2.88         29.80          89.0
# 4     13.96      9.18      2.93         2.84         28.92          58.0
#
#    Critic_Count  User_Score  User_Count Developer Rating  Year_of_ten
# ...

# %%
# 데이터프레임의 아래 20행을 불러와 봅시다!!
# df.tail(20)
df.tail(20)
# Out:
#                                    Name Platform  Year_of_Release  \
# 6805        Wade Hixton's Counter Punch      GBA           2004.0
# 6806                    Sega Rally Revo       PC           2007.0
# 6807       Egg Mania: Eggstreme Madness       GC           2002.0
# 6808       The Eye of Judgment: Legends      PSP           2010.0
# 6809    King's Bounty: Armored Princess       PC           2009.0
# 6810    Transformers: Fall of Cybertron       PC           2012.0
# 6811                  Micro Machines V4      PS2           2006.0
# 6812        Saints Row: Gat out of Hell     XOne           2015.0
# 6813           Dragon Ball Z for Kinect     X360           2012.0
# 6814           Legacy of Kain: Defiance       PC           2003.0
# 6815                              Trine       PC           2009.0
# 6816                      Karnaaj Rally      GBA           2003.0
# 6817           Sébastien Loeb Rally Evo     XOne           2016.0
# ...

# %%
#데이터프레임의 한 열, 'Name'(제목) 컬럼만 불러와보도록 합시다!!
df['Name']
# Out:
#                                    Name Platform
# 0                            Wii Sports      Wii
# 1                        Mario Kart Wii      Wii
# 2                     Wii Sports Resort      Wii
# 3                 New Super Mario Bros.       DS
# 4                              Wii Play      Wii
# ...                                 ...      ...
# 6820         E.T. The Extra-Terrestrial      GBA
# 6821     Mortal Kombat: Deadly Alliance      GBA
# 6822  Metal Gear Solid V: Ground Zeroes       PC
# 6823                             Breach       PC
# 6824            STORM: Frontline Nation       PC
#
# [6825 rows x 2 columns]

# %%
#또, 제목 및 플랫폼을 불러와 봅시다!!
col = ['Name','Platform']
df[col]
# Out:
#                                    Name Platform
# 0                            Wii Sports      Wii
# 1                        Mario Kart Wii      Wii
# 2                     Wii Sports Resort      Wii
# 3                 New Super Mario Bros.       DS
# 4                              Wii Play      Wii
# ...                                 ...      ...
# 6820         E.T. The Extra-Terrestrial      GBA
# 6821     Mortal Kombat: Deadly Alliance      GBA
# 6822  Metal Gear Solid V: Ground Zeroes       PC
# 6823                             Breach       PC
# 6824            STORM: Frontline Nation       PC
#
# [6825 rows x 2 columns]

# %% [markdown]
# 위 비디오게임의 판매량 및 등급 데이터셋(video_games_sales.csv)을 이용하여,
#
# A. 출시년도(Year_of_Release)를 10년 단위로 나누어 봅시다.
#
# 예를 들어, 출시년도가 1990~1999년이면 1990으로,
#
# 2000~2009년이면 2000으로,
#
# 2010~2019년이면 2010으로 표기하여
#
# 그룹을 나눠 봅시다!!
#
# =================
#
# B. 이 그룹들 중 게임이 가장 많이 출시된 기간(10년단위)와
#
# 게임이 가장 적게 출시된 기간(10년단위)를 구해 봅시다!!

# %%
# 위 데이터프레임에서, 'Year_of_Release' (출시년도) 컬럼만 불러와 봅시다!!
df['Year_of_Release']
# Out:
# 0       2006.0
# 1       2008.0
# 2       2009.0
# 3       2006.0
# 4       2006.0
#          ...
# 6820    2001.0
# 6821    2002.0
# 6822    2014.0
# 6823    2011.0
# 6824    2011.0
# Name: Year_of_Release, Length: 6825, dtype: float64

# %%
#위 데이터프레임에서, 20행부터 40행까지만을 불러와 봅시다!!
df[20:40]
# Out:
#                               Name Platform  Year_of_Release       Genre  \
# 20      Call of Duty: Black Ops II     X360           2012.0     Shooter
# 21  Call of Duty: Modern Warfare 2     X360           2009.0     Shooter
# 22  Call of Duty: Modern Warfare 3      PS3           2011.0     Shooter
# 23            Grand Theft Auto III      PS2           2001.0      Action
# 24         Super Smash Bros. Brawl      Wii           2008.0    Fighting
# 25                    Mario Kart 7      3DS           2011.0      Racing
# 26         Call of Duty: Black Ops      PS3           2010.0     Shooter
# 27              Grand Theft Auto V      PS4           2014.0      Action
# 28     Animal Crossing: Wild World       DS           2005.0  Simulation
# 29                          Halo 3     X360           2007.0     Shooter
# 30                  Gran Turismo 4      PS2           2004.0      Racing
# 31              Super Mario Galaxy      Wii           2007.0    Platform
# ...

# %%
#위 데이터프레임에서, Platform이 x360인 데이터만을 필터링해 봅시다!!
condition = (df['Platform'] == 'X360')
df[condition]
# Out:
#                                    Name Platform  Year_of_Release      Genre  \
# 8                    Kinect Adventures!     X360           2010.0       Misc
# 13                   Grand Theft Auto V     X360           2013.0     Action
# 17       Call of Duty: Modern Warfare 3     X360           2011.0    Shooter
# 18              Call of Duty: Black Ops     X360           2010.0    Shooter
# 20           Call of Duty: Black Ops II     X360           2012.0    Shooter
# ...                                 ...      ...              ...        ...
# 6640   The Testament of Sherlock Holmes     X360           2012.0  Adventure
# 6643  Marvel Avengers: Battle for Earth     X360           2012.0     Action
# 6667                              Worms     X360           2007.0   Strategy
# 6766                      Banjo-Kazooie     X360           2008.0   Platform
# 6813           Dragon Ball Z for Kinect     X360           2012.0   Fighting
#
# ...

# %%
# 위 데이터프레임에서, Year_of_Release가 2010보다 큰 경우를 필터링해 봅시다!!
condition2 = (df['Year_of_Release'] > 2010)
df[condition2]
# Out:
#                                    Name Platform  Year_of_Release     Genre  \
# 10                   Grand Theft Auto V      PS3           2013.0    Action
# 13                   Grand Theft Auto V     X360           2013.0    Action
# 17       Call of Duty: Modern Warfare 3     X360           2011.0   Shooter
# 19           Call of Duty: Black Ops II      PS3           2012.0   Shooter
# 20           Call of Duty: Black Ops II     X360           2012.0   Shooter
# ...                                 ...      ...              ...       ...
# 6817           Sébastien Loeb Rally Evo     XOne           2016.0    Racing
# 6819                   Fast Racing Neo      WiiU           2016.0    Action
# 6822  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 6823                             Breach       PC           2011.0   Shooter
# 6824            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %% [markdown]
# 이 비디오게임의 판매 및 등급량 데이터셋에서, 오른쪽에 컬럼을 하나 더 만들어
# '10년 단위' 분류를 해 보도록 하겠습니다!!
#
# 잘 따라와주세요!!

# %%
#10년 단위로 년도를 쪼갭니다. - 이후 'Year_of_ten'이라는 새 컬럼에 저장합니다. ^^
df['Year_of_ten'] = df['Year_of_Release'].map(lambda x: x//10*10)

Max = int(df.Year_of_ten.value_counts().index[0])
Min = int(df.Year_of_ten.value_counts().index[-1])

# %% [markdown]
# *아래는 lambda x: x//10 * 10에 대한 부가설명입니다!!

# %%
df['Year_of_Release'] // 10
# Out:
# 0       200.0
# 1       200.0
# 2       200.0
# 3       200.0
# 4       200.0
#         ...
# 6820    200.0
# 6821    200.0
# 6822    201.0
# 6823    201.0
# 6824    201.0
# Name: Year_of_Release, Length: 6825, dtype: float64

# %%
df['Year_of_Release'] // 10 * 10
# Out:
# 0       2000.0
# 1       2000.0
# 2       2000.0
# 3       2000.0
# 4       2000.0
#          ...
# 6820    2000.0
# 6821    2000.0
# 6822    2010.0
# 6823    2010.0
# 6824    2010.0
# Name: Year_of_Release, Length: 6825, dtype: float64

# %%
# 간편설명을 위해 출시년도('Year_of_Release')열의 5개 행만을 불러와 봅니다!!

df['Year_of_Release'][0:5]
# Out:
# 0    2006.0
# 1    2008.0
# 2    2009.0
# 3    2006.0
# 4    2006.0
# Name: Year_of_Release, dtype: float64

# %%
#필터링을 합니다. map함수 사용!!
df['Year_of_Release'][0:5].map(lambda x: x//10*10)
# Out:
# 0    2000.0
# 1    2000.0
# 2    2000.0
# 3    2000.0
# 4    2000.0
# Name: Year_of_Release, dtype: float64

# %%
# 0~5행만을 필터링한 것을 제거해 볼까요? ^^*
df['Year_of_Release'].map(lambda x: x//10*10)
# 아래와 같이 출력됩니다!!
# Out:
# 0       2000.0
# 1       2000.0
# 2       2000.0
# 3       2000.0
# 4       2000.0
#          ...
# 6820    2000.0
# 6821    2000.0
# 6822    2010.0
# 6823    2010.0
# 6824    2010.0
# Name: Year_of_Release, Length: 6825, dtype: float64

# %% [markdown]
# 이 내용을 'Year_of_ten'이라는 열(컬럼, column)을 새로 만들어 저장해 줍니다!!

# %%
# 'Year_of_ten'이라는 열(컬럼, column)에 연산 내용 저장하기.
df['Year_of_ten'] = df['Year_of_Release'].map(lambda x: x//10*10)

# %%
#Year_of_ten이라는 컬럼이 새로 생성되었습니다!!
df
# Out:
#                                    Name Platform  Year_of_Release     Genre  \
# 0                            Wii Sports      Wii           2006.0    Sports
# 1                        Mario Kart Wii      Wii           2008.0    Racing
# 2                     Wii Sports Resort      Wii           2009.0    Sports
# 3                 New Super Mario Bros.       DS           2006.0  Platform
# 4                              Wii Play      Wii           2006.0      Misc
# ...                                 ...      ...              ...       ...
# 6820         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 6821     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 6822  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 6823                             Breach       PC           2011.0   Shooter
# 6824            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
#컬럼명을 출력해 봅시다!!
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating',
#        'Year_of_ten'],
#       dtype='object')

# %% [markdown]
# Part II.

# %% [markdown]
# A. 게임 출시작 중 '플레이스테이션 시리즈' - PS, PS2, PS3, PS4, PSV 이면서
#
#           &
#
# Action 장르인 게임을 필터링하고
#
# 그 총 개수를 세어 봅시다!!

# %%
#컬럼을 지정합니다!! PS 시리즈
val_ps = ['PS','PS2','PS3','PS4','PSV']

# 이 결과에는 'Platform'행의 값이 위 'PS','PS2','PS3','PS4','PSV'에 
# 포함되는지를 True / False로 나타냅니다.
# ** isin = is in ~에 포함되는가?
df.Platform.isin(val_ps)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6820    False
# 6821    False
# 6822    False
# 6823    False
# 6824    False
# Name: Platform, Length: 6825, dtype: bool

# %%
# 'Genre'컬럼이 'Action'이면 'True'값을 출력합니다!!
df.Genre=='Action'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6820     True
# 6821    False
# 6822     True
# 6823    False
# 6824    False
# Name: Genre, Length: 6825, dtype: bool

# %%
# 두 조건에 그리고 / AND / &를 걸어 봅시다!!
condition3 = df.Platform.isin(['PS','PS2','PS3','PS4','PSV']) & (df.Genre=='Action')
print(condition)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6820    False
# 6821    False
# 6822    False
# 6823    False
# 6824    False
# Name: Platform, Length: 6825, dtype: bool

# %%
df[condition3]
# PS 시리즈이면서 'Action'인 결과를 출력합니다!!
# Out:
#                                Name Platform  Year_of_Release   Genre  \
# 10               Grand Theft Auto V      PS3           2013.0  Action
# 11    Grand Theft Auto: San Andreas      PS2           2004.0  Action
# 14      Grand Theft Auto: Vice City      PS2           2002.0  Action
# 23             Grand Theft Auto III      PS2           2001.0  Action
# 27               Grand Theft Auto V      PS4           2014.0  Action
# ...                             ...      ...              ...     ...
# 6720                     Just Cause      PS2           2006.0  Action
# 6732                     Republique      PS4           2016.0  Action
# 6774                         Dokuro      PSV           2012.0  Action
# 6792             Super Dungeon Bros      PS4           2016.0  Action
# 6801        Carmageddon: Max Damage      PS4           2016.0  Action
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
# 위 데이터프레임의 길이(행의 개수)를 출력해봅시다!!
len(df[condition3])
# Out:
# 616

# %% [markdown]
# B. 게임이 400개 이상 출시된 플랫폼을 정리하고,
#
# 각 플랫폼마다 User_Score의 평균값을 구하고 내림차순으로 정리하여 출력하세요!!

# %%
df.Platform.value_counts()
# Out:
# PS2     1140
# X360     858
# PS3      769
# PC       651
# XB       565
# Wii      479
# DS       464
# PSP      390
# GC       348
# PS4      239
# GBA      237
# XOne     159
# 3DS      155
# PS       150
# PSV      118
# WiiU      89
# DC        14
# Name: Platform, dtype: int64

# %%
condition5 = (df.Platform.value_counts()>=400)
condition5
# Out:
# PS2      True
# X360     True
# PS3      True
# PC       True
# XB       True
# Wii      True
# DS       True
# PSP     False
# GC      False
# PS4     False
# GBA     False
# XOne    False
# 3DS     False
# PS      False
# PSV     False
# WiiU    False
# DC      False
# Name: Platform, dtype: bool

# %%
platform_over_400 = df.Platform.value_counts()[condition5].index
# platform_over_400 = condition5.index
platform_over_400
# Out:
# Index(['PS2', 'X360', 'PS3', 'PC', 'XB', 'Wii', 'DS'], dtype='object')

# %%
df.Platform.isin(platform_over_400)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 6820    False
# 6821    False
# 6822     True
# 6823     True
# 6824     True
# Name: Platform, Length: 6825, dtype: bool

# %%
Ans= df.loc[df.Platform.isin(platform_over_400)].groupby('Platform')['User_Score'].mean().sort_values(ascending=False).to_frame()
Ans
# Out:
#           User_Score
# Platform
# PS2         7.664386
# XB          7.540708
# PC          7.060369
# DS          7.047198
# Wii         6.903758
# PS3         6.782705
# X360        6.780769

# %%
Part III.

게임 이름에 Mario가 들어가는 게임을 3회 개발한 개발자('Developer'열)을 
모두 찾아 봅시다!!

# %%
target = df[df.Name.str.contains('Mario')].Developer.value_counts()
Ans = list(target[target==3].index)

# %%
print(Ans)
# Out:
# ['Nintendo, Nd Cube', 'Nintendo, Nintendo Software Technology']

# %% [markdown]
# ```{admonition} Question 4
# **PS2 플랫폼으로 출시된 게임들의 User_Score의 첨도를 구하여라**
# ```

# %%
Ans = df[df.Platform=='PS2'].User_Score.kurtosis()

# %%
Ans
# Out:
# 2.4920035946875965

# %% [markdown]
# ```{admonition} Question 5
# **각 게임별 NA_Sales,EU_Sales,JP_Sales,Other_Sales 값의 합은 Global_Sales와 동일해야한다. 소숫점 2자리 이하의 생략으로 둘의 값의 다른경우가 존재하는데, 이러한 케이스가 몇개 있는지 확인하라**
# ```

# %%
# 일반적으로 boolen 타입의 True는 1로 인식하기에 전체 합을 구한다.
Ans = (df[['NA_Sales','EU_Sales','JP_Sales','Other_Sales']].sum(axis=1) != df['Global_Sales']).sum()

# %%
Ans
# Out:
# 3636

# %% [markdown]
# ```{admonition} Question 6
# **User_Count컬럼의 값이 120 이상인 게임들 중에서 User_Score의 값이 9.0이상인 게임의 수를 구하여라**
# ```

# %%
Ans = len(df[(df.User_Count >=120) & (df.User_Score >=9.0)])

# %%
Ans
# Out:
# 86

# %% [markdown]
# ```{admonition} Question 7
# **Global_Sales컬럼의 값들을 robust스케일을 진행하고 40이상인 데이터 수를 구하여라**
# ```

# %%
from  sklearn.preprocessing import RobustScaler

rb = RobustScaler()

rb_fit = rb.fit_transform(df.Global_Sales.values.reshape(-1,1))

Ans = len(rb_fit[rb_fit>40])

# %%
Ans
# Out:
# 6
